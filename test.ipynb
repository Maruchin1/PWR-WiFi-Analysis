# %%
import DataLoader

# %%
path = 'data_2015/2015-11'
data = DataLoader.load_from_folder(path)
data
# Out:
#              Date   Time                 ApName  NumOfClients  \
# 0      2015-11-01  00-00               AP-A10-5           1.0
# 1      2015-11-01  00-00               AP-A10-2           0.0
# 2      2015-11-01  00-00               Ustka-p1           0.0
# 3      2015-11-01  00-00   AP-C7-1cdf.0fac.9104           0.0
# 4      2015-11-01  00-00          C6-biblioteka           1.0
# ...           ...    ...                    ...           ...
# 83515  2015-11-30  23-55  AP-SKS-7c69.f604.b0a0           0.0
# 83516  2015-11-30  23-55  AP-SKS-7c69.f604.b0b1           2.0
# 83517  2015-11-30  23-55  AP-SKS-7c69.f604.b0b3           1.0
# 83518  2015-11-30  23-55  AP-SKS-7c69.f604.b0bf           2.0
# 83519  2015-11-30  23-55  AP-SKS-7c69.f604.b0c3           2.0
#
#        TransmittedFrames  ChannelUtilization  PoorSnrClients      Retries  \
# 0           3.259789e+07                 1.0             0.0     952726.0
# ...
